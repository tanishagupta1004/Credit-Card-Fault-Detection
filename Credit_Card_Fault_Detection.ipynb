# %%
import pandas as pd
import numpy as np

# %% [markdown]
# LIMIT_BAL: This feature represents the credit limit assigned to the individual's credit card. It indicates the maximum amount of credit the person can utilize.
#
# SEX: This feature represents the gender of the credit card holder. While gender itself may not directly impact credit card fault detection, it can be considered as a demographic factor that might have some influence on creditworthiness.
#
# EDUCATION: This feature indicates the educational background of the credit card holder. It can provide insights into the person's level of education, which might indirectly correlate with their financial stability and ability to manage credit.
#
# MARRIAGE: This feature represents the marital status of the credit card holder. Similar to gender, marital status can be a demographic factor that could potentially impact credit card fault detection.
#
# AGE: This feature denotes the age of the credit card holder. Age can be an important factor in assessing creditworthiness as it often correlates with financial responsibility and stability.
#
# PAY_0, PAY_2, PAY_3, PAY_4, PAY_5, PAY_6: These features represent the repayment status of the credit card for the past six months. The values indicate the payment status (e.g., -1 represents payment delay for one month, 0 represents payment on time, 1 represents payment delay for two months, and so on). These features are crucial in determining the payment behavior of the individual over time.
#
# BILL_AMT1, BILL_AMT2, BILL_AMT3, BILL_AMT4, BILL_AMT5, BILL_AMT6: These features represent the amount of bill statement for the respective months. They provide information about the outstanding balance on the credit card at specific points in time.
#
# PAY_AMT1, PAY_AMT2, PAY_AMT3, PAY_AMT4, PAY_AMT5, PAY_AMT6: These features represent the amount of payment made by the credit card holder for the respective months. They indicate the actual payments made to reduce the outstanding balance.
#
# default payment next month: This is the target variable or the dependent variable that indicates whether the credit card holder defaulted on their payment in the following month (1 for default, 0 for no default). This is the variable that the credit card fault detection model aims to predict.

# %%
data=pd.read_csv("https://raw.githubusercontent.com/sunnysavita10/credit_card_pw_hindi/main/creditCardFraud_28011964_120214.csv")

# %%
data
# Out:
#       LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0         50000    1          2         1   57     -1      0     -1      0
# 1         50000    1          1         2   37      0      0      0      0
# 2        500000    1          1         2   29      0      0      0      0
# 3        100000    2          2         2   23      0     -1     -1      0
# 4        140000    2          3         1   28      0      0      2      0
# ...         ...  ...        ...       ...  ...    ...    ...    ...    ...
# 996      100000    1          2         1   29      0      0      0      0
# 997      200000    2          2         1   28      0      0      0      0
# 998       90000    2          2         1   40     -1     -1     -1     -1
# 999      360000    1          1         2   36      1     -2     -2     -2
# 1000     150000    2          3         2   30     -2     -2     -2     -2
#
#       PAY_5  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# 0         0  ...      20940      19146      19131      2000     36681
# 1         0  ...      19394      19619      20024      2500      1815
# 2         0  ...     542653     483003     473944     55000     40000
# 3         0  ...        221       -159        567       380       601
# 4         0  ...      12211      11793       3719      3329         0
# ...     ...  ...        ...        ...        ...       ...       ...
# 996      -1  ...      -2618      95748     101299      3320      5000
# 997       0  ...      97041     103541       3632      5000      2000
# 998      -1  ...        657       1332        780         0      2806
# 999      -2  ...          0          0          0         0         0
# 1000     -2  ...       2527          0          0      9664      3420
#
#       PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# 0        10000      9000       689       679                           0
# 1          657      1000      1000       800                           0
# 2        38000     20239     13750     13770                           0
# 3            0       581      1687      1542                           0
# 4          432      1000      1000      1000                           0
# ...        ...       ...       ...       ...                         ...
# 996          0    100000      7186         0                           0
# 997      89000      6500        91      1504                           0
# 998       2256      2274       780         0                           0
# 999          0         0         0         0                           1
# 1000      2612         0         0         0                           1
#
# [1001 rows x 24 columns]

# %%
data.describe()
# Out:
#            LIMIT_BAL          SEX    EDUCATION     MARRIAGE          AGE  \
# count    1001.000000  1001.000000  1001.000000  1001.000000  1001.000000
# mean   167532.467532     1.589411     1.776224     1.604396    34.945055
# std    130587.921320     0.492187     0.750916     0.532298     9.219760
# min     10000.000000     1.000000     1.000000     0.000000    21.000000
# 25%     50000.000000     1.000000     1.000000     1.000000    28.000000
# 50%    140000.000000     2.000000     2.000000     2.000000    33.000000
# 75%    240000.000000     2.000000     2.000000     2.000000    41.000000
# max    700000.000000     2.000000     6.000000     3.000000    75.000000
#
#              PAY_0        PAY_2        PAY_3        PAY_4        PAY_5  ...  \
# count  1001.000000  1001.000000  1001.000000  1001.000000  1001.000000  ...
# mean     -0.004995    -0.161838    -0.164835    -0.283716    -0.283716  ...
# std       1.173446     1.228732     1.262459     1.184662     1.170224  ...
# min      -2.000000    -2.000000    -2.000000    -2.000000    -2.000000  ...
# 25%      -1.000000    -1.000000    -1.000000    -1.000000    -1.000000  ...
# 50%       0.000000     0.000000     0.000000     0.000000     0.000000  ...
# 75%       0.000000     0.000000     0.000000     0.000000     0.000000  ...
# max       8.000000     7.000000     7.000000     7.000000     7.000000  ...
#
#            BILL_AMT4      BILL_AMT5      BILL_AMT6       PAY_AMT1  \
# count    1001.000000    1001.000000    1001.000000    1001.000000
# mean    40748.408591   39078.666334   38012.011988    5382.339660
# std     68206.929510   63108.238729   63074.415024   12180.755275
# min     -3684.000000  -28335.000000 -339603.000000       0.000000
# 25%      1423.000000    1206.000000     830.000000    1000.000000
# 50%     17710.000000   17580.000000   15846.000000    2184.000000
# 75%     48851.000000   46404.000000   46557.000000    5090.000000
# max    628699.000000  484612.000000  473944.000000  199646.000000
#
#             PAY_AMT2       PAY_AMT3       PAY_AMT4       PAY_AMT5  \
# count    1001.000000    1001.000000    1001.000000    1001.000000
# mean     5051.400599    4176.149850    4671.488511    5331.049950
# std     15626.153184   10514.647502   13269.943983   16812.536877
# min         0.000000       0.000000       0.000000       0.000000
# 25%       390.000000     228.000000     148.000000     189.000000
# 50%      1710.000000    1206.000000    1398.000000    1306.000000
# 75%      4500.000000    3720.000000    4000.000000    3745.000000
# max    285138.000000  133657.000000  188840.000000  195599.000000
#
#             PAY_AMT6  default payment next month
# count    1001.000000                 1001.000000
# mean     5090.704296                    0.213786
# std     23658.888052                    0.410183
# min         0.000000                    0.000000
# 25%         0.000000                    0.000000
# 50%      1250.000000                    0.000000
# 75%      3784.000000                    0.000000
# max    528666.000000                    1.000000
#
# [8 rows x 24 columns]

# %%
#pip install pandas-profiling

# %%
from pandas_profiling import ProfileReport

# %%
profile=ProfileReport(data, title="pandas profiling report")

# %%
profile.to_widgets()
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render widgets:   0%|          | 0/1 [00:00<?, ?it/s]
# VBox(children=(Tab(children=(Tab(children=(GridBox(children=(VBox(children=(GridspecLayout(children=(HTML(valu…

# %%
x=data.drop(labels=["default payment next month"], axis=1)

# %%
y=data["default payment next month"]

# %%
x
# Out:
#       LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0         50000    1          2         1   57     -1      0     -1      0
# 1         50000    1          1         2   37      0      0      0      0
# 2        500000    1          1         2   29      0      0      0      0
# 3        100000    2          2         2   23      0     -1     -1      0
# 4        140000    2          3         1   28      0      0      2      0
# ...         ...  ...        ...       ...  ...    ...    ...    ...    ...
# 996      100000    1          2         1   29      0      0      0      0
# 997      200000    2          2         1   28      0      0      0      0
# 998       90000    2          2         1   40     -1     -1     -1     -1
# 999      360000    1          1         2   36      1     -2     -2     -2
# 1000     150000    2          3         2   30     -2     -2     -2     -2
#
#       PAY_5  ...  BILL_AMT3  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  \
# 0         0  ...      35835      20940      19146      19131      2000
# 1         0  ...      57608      19394      19619      20024      2500
# 2         0  ...     445007     542653     483003     473944     55000
# 3         0  ...        601        221       -159        567       380
# 4         0  ...      12108      12211      11793       3719      3329
# ...     ...  ...        ...        ...        ...        ...       ...
# 996      -1  ...      67782      -2618      95748     101299      3320
# 997       0  ...       8441      97041     103541       3632      5000
# 998      -1  ...       1114        657       1332        780         0
# 999      -2  ...          0          0          0          0         0
# 1000     -2  ...       3420       2527          0          0      9664
#
#       PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6
# 0        36681     10000      9000       689       679
# 1         1815       657      1000      1000       800
# 2        40000     38000     20239     13750     13770
# 3          601         0       581      1687      1542
# 4            0       432      1000      1000      1000
# ...        ...       ...       ...       ...       ...
# 996       5000         0    100000      7186         0
# 997       2000     89000      6500        91      1504
# 998       2806      2256      2274       780         0
# 999          0         0         0         0         0
# 1000      3420      2612         0         0         0
#
# [1001 rows x 23 columns]

# %%
y
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 996     0
# 997     0
# 998     0
# 999     1
# 1000    1
# Name: default payment next month, Length: 1001, dtype: int64

# %%
[10,20,30,40,50]
# Out:
# [10, 20, 30, 40, 50]

# %%
df=pd.DataFrame([10,20,30,40,50])

# %%
df
# Out:
#     0
# 0  10
# 1  20
# 2  30
# 3  40
# 4  50

# %%
mean=np.mean([10,20,30,40,50])
mean
# Out:
# 30.0

# %%
meanbycol=df-mean

# %%
std=np.std([10,20,30,40,50])
std
# Out:
# 14.142135623730951

# %%
meanbycol/std
# Out:
#           0
# 0 -1.414214
# 1 -0.707107
# 2  0.000000
# 3  0.707107
# 4  1.414214

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=20)

# %%
x_train
# Out:
#      LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 900      80000    2          2         2   40      2      0      0      0
# 439     200000    2          1         2   27      0      0      0      0
# 614      60000    1          1         2   25      0      0      0      0
# 696     400000    2          2         2   40     -2     -2     -2     -2
# 128     420000    1          2         1   34      0      0      0      0
# ..         ...  ...        ...       ...  ...    ...    ...    ...    ...
# 924     180000    2          1         2   36     -2     -2     -2     -2
# 223      20000    1          2         1   37      0      0      0      0
# 271      70000    2          2         2   36      0      0      0      0
# 474     500000    2          1         1   38     -1      2     -1     -1
# 355     260000    1          1         1   34     -1     -1     -1     -1
#
#      PAY_5  ...  BILL_AMT3  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  \
# 900      2  ...      59863      62860      63976      63293      2200
# 439      0  ...     126355     114881     117213     124793      5704
# 614      0  ...      38533      39639      39619      39140      2018
# 696     -1  ...          0          0       1524          0      8235
# 128      0  ...     229049     220951     210606     188108      9744
# ..     ...  ...        ...        ...        ...        ...       ...
# 924     -2  ...      11936      40420       9210      17795     21197
# 223      0  ...      18902      18768      18650      19175      1609
# 271      0  ...      68376      30163      14310      15085      4483
# 474     -1  ...        501        300        600        450         0
# 355     -1  ...      51058       2351      34039        291       291
#
#      PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6
# 900      2200      4000      1777         0      2000
# 439      5930      4000      4003     10033      4400
# 614      1900      2000      1500      1900      2000
# 696         0         0      1524         0       385
# 128      9553      7603      7830      7253     11326
# ..        ...       ...       ...       ...       ...
# 924     11936     40420      9210     17795      6915
# 223      3000       663       676       834       782
# 271     12496      3268      3000      3000      2000
# 474       501       300       600       300       600
# 355     51058     35696     34039       291       291
#
# [750 rows x 23 columns]

# %%
x_test
# Out:
#      LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 891     200000    1          1         2   31     -2     -2     -2     -2
# 694     280000    1          1         1   41     -2     -2     -2     -2
# 798      50000    2          3         1   44     -1     -1     -1     -1
# 147      80000    1          1         2   25      0      0      0      0
# 859      10000    2          2         1   31      0      0      0      0
# ..         ...  ...        ...       ...  ...    ...    ...    ...    ...
# 172      80000    1          1         2   30     -2     -1      0      0
# 835     500000    1          1         1   43      1     -2     -2     -2
# 601      50000    1          1         2   34      1      2      2      2
# 171     130000    1          3         1   56      1      2      2      2
# 826     320000    1          1         2   28     -1      0      0     -1
#
#      PAY_5  ...  BILL_AMT3  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  \
# 891     -2  ...        100        100        100        100       100
# 694     -1  ...      51500      35752       3955      13969     41346
# 798      0  ...          0       7472      10174      11104       780
# 147      0  ...      43476      41087      41951      31826     30000
# 859      0  ...       9901       9975       9736       8703      2330
# ..     ...  ...        ...        ...        ...        ...       ...
# 172      0  ...        600       1438       1919       5380       504
# 835     -2  ...          0          0          0          0         0
# 601      2  ...      24121      23437      25101      24549         0
# 171      2  ...      67282      68557      72796      71345      3000
# 826      0  ...       3037       1633       3633          0      2000
#
#      PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6
# 891       100       100       100       100       100
# 694     52110     35752      3955     13939      4437
# 798         0      7472      3000      1104      1000
# 147      3000      6000      8000      2000     14000
# 859      2200      1000       333       311       322
# ..        ...       ...       ...       ...       ...
# 172       500      1000       500      3500         0
# 835         0         0         0         0         0
# 601      2700         0      2200         0      1030
# 171      3000      3000      5500         0         0
# 826      1000      1633      2000         0      3000
#
# [251 rows x 23 columns]

# %%
from sklearn.preprocessing import StandardScaler
scalar=StandardScaler()

# %%
scaled_train=scalar.fit_transform(x_train)
scaled_test=scalar.fit_transform(x_test)

# %%
new_obj=StandardScaler()

# %%
scale_data=new_obj.fit_transform(df)

# %%
scale_data
# Out:
# array([[-1.41421356],
#        [-0.70710678],
#        [ 0.        ],
#        [ 0.70710678],
#        [ 1.41421356]])

# %% [markdown]
# ## Naive Bayes Algorithm

# %%
from sklearn.naive_bayes import GaussianNB
clf=GaussianNB()
clf.fit(scaled_train,y_train)
# Out:
# GaussianNB()

# %%
from sklearn.metrics import accuracy_score
y_pred=clf.predict(scaled_test)
accuracy_score(y_test,y_pred)*100
# Out:
# 70.91633466135458

# %% [markdown]
# HyperParameter Tuning Concept

# %%
param_grid={"var_smoothing":[0.1, 0.001, 0.5,0.05,0.01,1e-8,1e-7,1e-6,1e-10,1e-11]}

# %%
from sklearn.model_selection import GridSearchCV

# %%
gs=GridSearchCV(clf,param_grid=param_grid,cv=5,verbose=3)

# %%
gs.fit(scaled_train,y_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV 1/5] END .................var_smoothing=0.1;, score=0.800 total time=   0.0s
# [CV 2/5] END .................var_smoothing=0.1;, score=0.720 total time=   0.0s
# [CV 3/5] END .................var_smoothing=0.1;, score=0.707 total time=   0.0s
# [CV 4/5] END .................var_smoothing=0.1;, score=0.800 total time=   0.0s
# [CV 5/5] END .................var_smoothing=0.1;, score=0.547 total time=   0.0s
# [CV 1/5] END ...............var_smoothing=0.001;, score=0.793 total time=   0.0s
# [CV 2/5] END ...............var_smoothing=0.001;, score=0.713 total time=   0.0s
# [CV 3/5] END ...............var_smoothing=0.001;, score=0.633 total time=   0.0s
# [CV 4/5] END ...............var_smoothing=0.001;, score=0.667 total time=   0.0s
# [CV 5/5] END ...............var_smoothing=0.001;, score=0.447 total time=   0.0s
# [CV 1/5] END .................var_smoothing=0.5;, score=0.793 total time=   0.0s
# [CV 2/5] END .................var_smoothing=0.5;, score=0.767 total time=   0.0s
# [CV 3/5] END .................var_smoothing=0.5;, score=0.747 total time=   0.0s
# [CV 4/5] END .................var_smoothing=0.5;, score=0.800 total time=   0.0s
# [CV 5/5] END .................var_smoothing=0.5;, score=0.740 total time=   0.0s
# [CV 1/5] END ................var_smoothing=0.05;, score=0.800 total time=   0.0s
# [CV 2/5] END ................var_smoothing=0.05;, score=0.713 total time=   0.0s
# [CV 3/5] END ................var_smoothing=0.05;, score=0.693 total time=   0.0s
# [CV 4/5] END ................var_smoothing=0.05;, score=0.747 total time=   0.0s
# [CV 5/5] END ................var_smoothing=0.05;, score=0.493 total time=   0.0s
# [CV 1/5] END ................var_smoothing=0.01;, score=0.800 total time=   0.0s
# [CV 2/5] END ................var_smoothing=0.01;, score=0.707 total time=   0.0s
# [CV 3/5] END ................var_smoothing=0.01;, score=0.647 total time=   0.0s
# [CV 4/5] END ................var_smoothing=0.01;, score=0.680 total time=   0.0s
# [CV 5/5] END ................var_smoothing=0.01;, score=0.467 total time=   0.0s
# [CV 1/5] END ...............var_smoothing=1e-08;, score=0.793 total time=   0.0s
# [CV 2/5] END ...............var_smoothing=1e-08;, score=0.713 total time=   0.0s
# [CV 3/5] END ...............var_smoothing=1e-08;, score=0.633 total time=   0.0s
# [CV 4/5] END ...............var_smoothing=1e-08;, score=0.667 total time=   0.0s
# [CV 5/5] END ...............var_smoothing=1e-08;, score=0.447 total time=   0.0s
# [CV 1/5] END ...............var_smoothing=1e-07;, score=0.793 total time=   0.0s
# [CV 2/5] END ...............var_smoothing=1e-07;, score=0.713 total time=   0.0s
# [CV 3/5] END ...............var_smoothing=1e-07;, score=0.633 total time=   0.0s
# [CV 4/5] END ...............var_smoothing=1e-07;, score=0.667 total time=   0.0s
# [CV 5/5] END ...............var_smoothing=1e-07;, score=0.447 total time=   0.0s
# [CV 1/5] END ...............var_smoothing=1e-06;, score=0.793 total time=   0.0s
# [CV 2/5] END ...............var_smoothing=1e-06;, score=0.713 total time=   0.0s
# [CV 3/5] END ...............var_smoothing=1e-06;, score=0.633 total time=   0.0s
# [CV 4/5] END ...............var_smoothing=1e-06;, score=0.667 total time=   0.0s
# [CV 5/5] END ...............var_smoothing=1e-06;, score=0.447 total time=   0.0s
# [CV 1/5] END ...............var_smoothing=1e-10;, score=0.793 total time=   0.0s
# [CV 2/5] END ...............var_smoothing=1e-10;, score=0.713 total time=   0.0s
# [CV 3/5] END ...............var_smoothing=1e-10;, score=0.633 total time=   0.0s
# [CV 4/5] END ...............var_smoothing=1e-10;, score=0.667 total time=   0.0s
# [CV 5/5] END ...............var_smoothing=1e-10;, score=0.447 total time=   0.0s
# [CV 1/5] END ...............var_smoothing=1e-11;, score=0.793 total time=   0.0s
# [CV 2/5] END ...............var_smoothing=1e-11;, score=0.713 total time=   0.0s
# [CV 3/5] END ...............var_smoothing=1e-11;, score=0.633 total time=   0.0s
# [CV 4/5] END ...............var_smoothing=1e-11;, score=0.667 total time=   0.0s
# [CV 5/5] END ...............var_smoothing=1e-11;, score=0.447 total time=   0.0s
# GridSearchCV(cv=5, estimator=GaussianNB(),
#              param_grid={'var_smoothing': [0.1, 0.001, 0.5, 0.05, 0.01, 1e-08,
#                                            1e-07, 1e-06, 1e-10, 1e-11]},
#              verbose=3)

# %%
gs.best_params_
# Out:
# {'var_smoothing': 0.5}

# %%
from sklearn.naive_bayes import GaussianNB
clf1 = GaussianNB(var_smoothing=0.5)
clf1.fit(scaled_train,y_train)
y_pred1=clf1.predict(scaled_test)
accuracy_score(y_test,y_pred1)*100
# Out:
# 80.87649402390437

# %% [markdown]
# ## Random Forest Algorithm

# %%
from sklearn.ensemble import RandomForestClassifier
rs=RandomForestClassifier()
rs.fit(scaled_train,y_train)
y_pred2=rs.predict(scaled_test)
accuracy_score(y_test,y_pred2)*100
# Out:
# 82.86852589641434

# %%
param_grid_rf = { "n_estimators": [50,100,130,200],
                    "max_depth": range(3,11,1),
                    "random_state":[0,50,100],
                     "criterion":['gini',"entropy"]
                     }

# %%
gs1=GridSearchCV(rs,param_grid=param_grid_rf,cv=5,verbose=3)

# %%
gs1.fit(scaled_train,y_train)
# Out:
# Fitting 5 folds for each of 192 candidates, totalling 960 fits
# [CV 1/5] END criterion=gini, max_depth=3, n_estimators=50, random_state=0;, score=0.780 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=3, n_estimators=50, random_state=0;, score=0.787 total time=   0.1s
# [CV 3/5] END criterion=gini, max_depth=3, n_estimators=50, random_state=0;, score=0.787 total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=3, n_estimators=50, random_state=0;, score=0.793 total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=3, n_estimators=50, random_state=0;, score=0.760 total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=3, n_estimators=50, random_state=50;, score=0.780 total time=   0.1s
# [CV 2/5] END criterion=gini, max_depth=3, n_estimators=50, random_state=50;, score=0.760 total time=   0.1s
# [CV 3/5] END criterion=gini, max_depth=3, n_estimators=50, random_state=50;, score=0.793 total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=3, n_estimators=50, random_state=50;, score=0.793 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=3, n_estimators=50, random_state=50;, score=0.780 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=3, n_estimators=50, random_state=100;, score=0.793 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=3, n_estimators=50, random_state=100;, score=0.787 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=3, n_estimators=50, random_state=100;, score=0.793 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=3, n_estimators=50, random_state=100;, score=0.800 total time=   0.3s
# [CV 5/5] END criterion=gini, max_depth=3, n_estimators=50, random_state=100;, score=0.760 total time=   0.4s
# [CV 1/5] END criterion=gini, max_depth=3, n_estimators=100, random_state=0;, score=0.780 total time=   1.1s
# [CV 2/5] END criterion=gini, max_depth=3, n_estimators=100, random_state=0;, score=0.767 total time=   1.4s
# [CV 3/5] END criterion=gini, max_depth=3, n_estimators=100, random_state=0;, score=0.787 total time=   2.1s
# [CV 4/5] END criterion=gini, max_depth=3, n_estimators=100, random_state=0;, score=0.793 total time=   2.1s
# [CV 5/5] END criterion=gini, max_depth=3, n_estimators=100, random_state=0;, score=0.767 total time=   1.6s
# [CV 1/5] END criterion=gini, max_depth=3, n_estimators=100, random_state=50;, score=0.780 total time=   1.9s
# [CV 2/5] END criterion=gini, max_depth=3, n_estimators=100, random_state=50;, score=0.760 total time=   2.1s
# [CV 3/5] END criterion=gini, max_depth=3, n_estimators=100, random_state=50;, score=0.800 total time=   2.4s
# [CV 4/5] END criterion=gini, max_depth=3, n_estimators=100, random_state=50;, score=0.807 total time=   1.5s
# [CV 5/5] END criterion=gini, max_depth=3, n_estimators=100, random_state=50;, score=0.773 total time=   0.7s
# [CV 1/5] END criterion=gini, max_depth=3, n_estimators=100, random_state=100;, score=0.780 total time=   0.6s
# [CV 2/5] END criterion=gini, max_depth=3, n_estimators=100, random_state=100;, score=0.780 total time=   0.5s
# [CV 3/5] END criterion=gini, max_depth=3, n_estimators=100, random_state=100;, score=0.800 total time=   0.5s
# [CV 4/5] END criterion=gini, max_depth=3, n_estimators=100, random_state=100;, score=0.793 total time=   0.4s
# [CV 5/5] END criterion=gini, max_depth=3, n_estimators=100, random_state=100;, score=0.773 total time=   0.4s
# [CV 1/5] END criterion=gini, max_depth=3, n_estimators=130, random_state=0;, score=0.780 total time=   0.5s
# [CV 2/5] END criterion=gini, max_depth=3, n_estimators=130, random_state=0;, score=0.760 total time=   0.5s
# [CV 3/5] END criterion=gini, max_depth=3, n_estimators=130, random_state=0;, score=0.793 total time=   0.6s
# [CV 4/5] END criterion=gini, max_depth=3, n_estimators=130, random_state=0;, score=0.793 total time=   0.5s
# [CV 5/5] END criterion=gini, max_depth=3, n_estimators=130, random_state=0;, score=0.767 total time=   0.5s
# [CV 1/5] END criterion=gini, max_depth=3, n_estimators=130, random_state=50;, score=0.773 total time=   0.5s
# [CV 2/5] END criterion=gini, max_depth=3, n_estimators=130, random_state=50;, score=0.760 total time=   0.5s
# [CV 3/5] END criterion=gini, max_depth=3, n_estimators=130, random_state=50;, score=0.800 total time=   0.5s
# [CV 4/5] END criterion=gini, max_depth=3, n_estimators=130, random_state=50;, score=0.807 total time=   0.5s
# [CV 5/5] END criterion=gini, max_depth=3, n_estimators=130, random_state=50;, score=0.773 total time=   0.5s
# [CV 1/5] END criterion=gini, max_depth=3, n_estimators=130, random_state=100;, score=0.787 total time=   0.5s
# [CV 2/5] END criterion=gini, max_depth=3, n_estimators=130, random_state=100;, score=0.773 total time=   0.6s
# [CV 3/5] END criterion=gini, max_depth=3, n_estimators=130, random_state=100;, score=0.800 total time=   0.5s
# [CV 4/5] END criterion=gini, max_depth=3, n_estimators=130, random_state=100;, score=0.793 total time=   0.5s
# [CV 5/5] END criterion=gini, max_depth=3, n_estimators=130, random_state=100;, score=0.767 total time=   0.5s
# [CV 1/5] END criterion=gini, max_depth=3, n_estimators=200, random_state=0;, score=0.780 total time=   0.9s
# [CV 2/5] END criterion=gini, max_depth=3, n_estimators=200, random_state=0;, score=0.760 total time=   0.8s
# [CV 3/5] END criterion=gini, max_depth=3, n_estimators=200, random_state=0;, score=0.787 total time=   0.8s
# [CV 4/5] END criterion=gini, max_depth=3, n_estimators=200, random_state=0;, score=0.787 total time=   0.9s
# [CV 5/5] END criterion=gini, max_depth=3, n_estimators=200, random_state=0;, score=0.767 total time=   0.8s
# [CV 1/5] END criterion=gini, max_depth=3, n_estimators=200, random_state=50;, score=0.780 total time=   0.8s
# [CV 2/5] END criterion=gini, max_depth=3, n_estimators=200, random_state=50;, score=0.760 total time=   1.0s
# [CV 3/5] END criterion=gini, max_depth=3, n_estimators=200, random_state=50;, score=0.793 total time=   0.8s
# [CV 4/5] END criterion=gini, max_depth=3, n_estimators=200, random_state=50;, score=0.807 total time=   1.0s
# [CV 5/5] END criterion=gini, max_depth=3, n_estimators=200, random_state=50;, score=0.767 total time=   3.4s
# [CV 1/5] END criterion=gini, max_depth=3, n_estimators=200, random_state=100;, score=0.780 total time=   7.8s
# [CV 2/5] END criterion=gini, max_depth=3, n_estimators=200, random_state=100;, score=0.760 total time=  10.2s
# [CV 3/5] END criterion=gini, max_depth=3, n_estimators=200, random_state=100;, score=0.793 total time=   5.0s
# [CV 4/5] END criterion=gini, max_depth=3, n_estimators=200, random_state=100;, score=0.787 total time=   0.9s
# [CV 5/5] END criterion=gini, max_depth=3, n_estimators=200, random_state=100;, score=0.767 total time=   0.8s
# [CV 1/5] END criterion=gini, max_depth=4, n_estimators=50, random_state=0;, score=0.773 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=4, n_estimators=50, random_state=0;, score=0.753 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=4, n_estimators=50, random_state=0;, score=0.787 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=4, n_estimators=50, random_state=0;, score=0.800 total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=4, n_estimators=50, random_state=0;, score=0.760 total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=4, n_estimators=50, random_state=50;, score=0.773 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=4, n_estimators=50, random_state=50;, score=0.760 total time=   0.1s
# [CV 3/5] END criterion=gini, max_depth=4, n_estimators=50, random_state=50;, score=0.780 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=4, n_estimators=50, random_state=50;, score=0.793 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=4, n_estimators=50, random_state=50;, score=0.747 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=4, n_estimators=50, random_state=100;, score=0.793 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=4, n_estimators=50, random_state=100;, score=0.767 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=4, n_estimators=50, random_state=100;, score=0.780 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=4, n_estimators=50, random_state=100;, score=0.793 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=4, n_estimators=50, random_state=100;, score=0.747 total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=4, n_estimators=100, random_state=0;, score=0.767 total time=   0.4s
# [CV 2/5] END criterion=gini, max_depth=4, n_estimators=100, random_state=0;, score=0.747 total time=   0.4s
# [CV 3/5] END criterion=gini, max_depth=4, n_estimators=100, random_state=0;, score=0.787 total time=   0.4s
# [CV 4/5] END criterion=gini, max_depth=4, n_estimators=100, random_state=0;, score=0.800 total time=   0.5s
# [CV 5/5] END criterion=gini, max_depth=4, n_estimators=100, random_state=0;, score=0.760 total time=   0.4s
# [CV 1/5] END criterion=gini, max_depth=4, n_estimators=100, random_state=50;, score=0.773 total time=   0.4s
# [CV 2/5] END criterion=gini, max_depth=4, n_estimators=100, random_state=50;, score=0.767 total time=   0.4s
# [CV 3/5] END criterion=gini, max_depth=4, n_estimators=100, random_state=50;, score=0.780 total time=   0.4s
# [CV 4/5] END criterion=gini, max_depth=4, n_estimators=100, random_state=50;, score=0.813 total time=   0.5s
# [CV 5/5] END criterion=gini, max_depth=4, n_estimators=100, random_state=50;, score=0.747 total time=   0.5s
# [CV 1/5] END criterion=gini, max_depth=4, n_estimators=100, random_state=100;, score=0.787 total time=   0.4s
# [CV 2/5] END criterion=gini, max_depth=4, n_estimators=100, random_state=100;, score=0.773 total time=   0.4s
# [CV 3/5] END criterion=gini, max_depth=4, n_estimators=100, random_state=100;, score=0.787 total time=   0.4s
# [CV 4/5] END criterion=gini, max_depth=4, n_estimators=100, random_state=100;, score=0.780 total time=   0.4s
# [CV 5/5] END criterion=gini, max_depth=4, n_estimators=100, random_state=100;, score=0.747 total time=   0.5s
# [CV 1/5] END criterion=gini, max_depth=4, n_estimators=130, random_state=0;, score=0.773 total time=   0.5s
# [CV 2/5] END criterion=gini, max_depth=4, n_estimators=130, random_state=0;, score=0.753 total time=   0.6s
# [CV 3/5] END criterion=gini, max_depth=4, n_estimators=130, random_state=0;, score=0.793 total time=   0.5s
# [CV 4/5] END criterion=gini, max_depth=4, n_estimators=130, random_state=0;, score=0.800 total time=   0.7s
# [CV 5/5] END criterion=gini, max_depth=4, n_estimators=130, random_state=0;, score=0.747 total time=   0.6s
# [CV 1/5] END criterion=gini, max_depth=4, n_estimators=130, random_state=50;, score=0.773 total time=   0.6s
# [CV 2/5] END criterion=gini, max_depth=4, n_estimators=130, random_state=50;, score=0.767 total time=   0.5s
# [CV 3/5] END criterion=gini, max_depth=4, n_estimators=130, random_state=50;, score=0.793 total time=   0.7s
# [CV 4/5] END criterion=gini, max_depth=4, n_estimators=130, random_state=50;, score=0.813 total time=   0.6s
# [CV 5/5] END criterion=gini, max_depth=4, n_estimators=130, random_state=50;, score=0.747 total time=   0.5s
# [CV 1/5] END criterion=gini, max_depth=4, n_estimators=130, random_state=100;, score=0.787 total time=   0.6s
# [CV 2/5] END criterion=gini, max_depth=4, n_estimators=130, random_state=100;, score=0.773 total time=   0.6s
# [CV 3/5] END criterion=gini, max_depth=4, n_estimators=130, random_state=100;, score=0.780 total time=   0.6s
# [CV 4/5] END criterion=gini, max_depth=4, n_estimators=130, random_state=100;, score=0.800 total time=   0.5s
# [CV 5/5] END criterion=gini, max_depth=4, n_estimators=130, random_state=100;, score=0.753 total time=   0.5s
# [CV 1/5] END criterion=gini, max_depth=4, n_estimators=200, random_state=0;, score=0.773 total time=   1.0s
# [CV 2/5] END criterion=gini, max_depth=4, n_estimators=200, random_state=0;, score=0.760 total time=   0.9s
# [CV 3/5] END criterion=gini, max_depth=4, n_estimators=200, random_state=0;, score=0.787 total time=   0.9s
# [CV 4/5] END criterion=gini, max_depth=4, n_estimators=200, random_state=0;, score=0.807 total time=   1.0s
# [CV 5/5] END criterion=gini, max_depth=4, n_estimators=200, random_state=0;, score=0.747 total time=   0.9s
# [CV 1/5] END criterion=gini, max_depth=4, n_estimators=200, random_state=50;, score=0.773 total time=   1.0s
# [CV 2/5] END criterion=gini, max_depth=4, n_estimators=200, random_state=50;, score=0.760 total time=   0.9s
# [CV 3/5] END criterion=gini, max_depth=4, n_estimators=200, random_state=50;, score=0.793 total time=   0.9s
# [CV 4/5] END criterion=gini, max_depth=4, n_estimators=200, random_state=50;, score=0.807 total time=   1.0s
# [CV 5/5] END criterion=gini, max_depth=4, n_estimators=200, random_state=50;, score=0.747 total time=   0.9s
# [CV 1/5] END criterion=gini, max_depth=4, n_estimators=200, random_state=100;, score=0.780 total time=   0.9s
# [CV 2/5] END criterion=gini, max_depth=4, n_estimators=200, random_state=100;, score=0.767 total time=   1.0s
# [CV 3/5] END criterion=gini, max_depth=4, n_estimators=200, random_state=100;, score=0.793 total time=   0.9s
# [CV 4/5] END criterion=gini, max_depth=4, n_estimators=200, random_state=100;, score=0.800 total time=   0.9s
# [CV 5/5] END criterion=gini, max_depth=4, n_estimators=200, random_state=100;, score=0.747 total time=   1.0s
# [CV 1/5] END criterion=gini, max_depth=5, n_estimators=50, random_state=0;, score=0.780 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=5, n_estimators=50, random_state=0;, score=0.760 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=5, n_estimators=50, random_state=0;, score=0.773 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=5, n_estimators=50, random_state=0;, score=0.800 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=5, n_estimators=50, random_state=0;, score=0.747 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=5, n_estimators=50, random_state=50;, score=0.780 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=5, n_estimators=50, random_state=50;, score=0.793 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=5, n_estimators=50, random_state=50;, score=0.793 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=5, n_estimators=50, random_state=50;, score=0.793 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=5, n_estimators=50, random_state=50;, score=0.767 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=5, n_estimators=50, random_state=100;, score=0.787 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=5, n_estimators=50, random_state=100;, score=0.773 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=5, n_estimators=50, random_state=100;, score=0.787 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=5, n_estimators=50, random_state=100;, score=0.793 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=5, n_estimators=50, random_state=100;, score=0.760 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=5, n_estimators=100, random_state=0;, score=0.773 total time=   0.5s
# [CV 2/5] END criterion=gini, max_depth=5, n_estimators=100, random_state=0;, score=0.767 total time=   0.5s
# [CV 3/5] END criterion=gini, max_depth=5, n_estimators=100, random_state=0;, score=0.787 total time=   0.5s
# [CV 4/5] END criterion=gini, max_depth=5, n_estimators=100, random_state=0;, score=0.813 total time=   0.5s
# [CV 5/5] END criterion=gini, max_depth=5, n_estimators=100, random_state=0;, score=0.747 total time=   0.5s
# [CV 1/5] END criterion=gini, max_depth=5, n_estimators=100, random_state=50;, score=0.767 total time=   0.5s
# [CV 2/5] END criterion=gini, max_depth=5, n_estimators=100, random_state=50;, score=0.760 total time=   0.5s
# [CV 3/5] END criterion=gini, max_depth=5, n_estimators=100, random_state=50;, score=0.787 total time=   0.5s
# [CV 4/5] END criterion=gini, max_depth=5, n_estimators=100, random_state=50;, score=0.807 total time=   0.6s
# [CV 5/5] END criterion=gini, max_depth=5, n_estimators=100, random_state=50;, score=0.753 total time=   0.5s
# [CV 1/5] END criterion=gini, max_depth=5, n_estimators=100, random_state=100;, score=0.780 total time=   0.4s
# [CV 2/5] END criterion=gini, max_depth=5, n_estimators=100, random_state=100;, score=0.767 total time=   0.4s
# [CV 3/5] END criterion=gini, max_depth=5, n_estimators=100, random_state=100;, score=0.787 total time=   0.4s
# [CV 4/5] END criterion=gini, max_depth=5, n_estimators=100, random_state=100;, score=0.800 total time=   0.5s
# [CV 5/5] END criterion=gini, max_depth=5, n_estimators=100, random_state=100;, score=0.760 total time=   0.5s
# [CV 1/5] END criterion=gini, max_depth=5, n_estimators=130, random_state=0;, score=0.773 total time=   0.6s
# [CV 2/5] END criterion=gini, max_depth=5, n_estimators=130, random_state=0;, score=0.753 total time=   0.6s
# [CV 3/5] END criterion=gini, max_depth=5, n_estimators=130, random_state=0;, score=0.787 total time=   0.7s
# [CV 4/5] END criterion=gini, max_depth=5, n_estimators=130, random_state=0;, score=0.807 total time=   0.8s
# [CV 5/5] END criterion=gini, max_depth=5, n_estimators=130, random_state=0;, score=0.747 total time=   0.6s
# [CV 1/5] END criterion=gini, max_depth=5, n_estimators=130, random_state=50;, score=0.767 total time=   0.6s
# [CV 2/5] END criterion=gini, max_depth=5, n_estimators=130, random_state=50;, score=0.767 total time=   0.7s
# [CV 3/5] END criterion=gini, max_depth=5, n_estimators=130, random_state=50;, score=0.787 total time=   0.6s
# [CV 4/5] END criterion=gini, max_depth=5, n_estimators=130, random_state=50;, score=0.813 total time=   0.6s
# [CV 5/5] END criterion=gini, max_depth=5, n_estimators=130, random_state=50;, score=0.753 total time=   0.7s
# [CV 1/5] END criterion=gini, max_depth=5, n_estimators=130, random_state=100;, score=0.787 total time=   0.7s
# [CV 2/5] END criterion=gini, max_depth=5, n_estimators=130, random_state=100;, score=0.767 total time=   0.6s
# [CV 3/5] END criterion=gini, max_depth=5, n_estimators=130, random_state=100;, score=0.793 total time=   0.6s
# [CV 4/5] END criterion=gini, max_depth=5, n_estimators=130, random_state=100;, score=0.800 total time=   0.6s
# [CV 5/5] END criterion=gini, max_depth=5, n_estimators=130, random_state=100;, score=0.753 total time=   0.6s
# [CV 1/5] END criterion=gini, max_depth=5, n_estimators=200, random_state=0;, score=0.773 total time=   1.0s
# [CV 2/5] END criterion=gini, max_depth=5, n_estimators=200, random_state=0;, score=0.767 total time=   1.0s
# [CV 3/5] END criterion=gini, max_depth=5, n_estimators=200, random_state=0;, score=0.773 total time=   1.0s
# [CV 4/5] END criterion=gini, max_depth=5, n_estimators=200, random_state=0;, score=0.813 total time=   1.0s
# [CV 5/5] END criterion=gini, max_depth=5, n_estimators=200, random_state=0;, score=0.747 total time=   1.1s
# [CV 1/5] END criterion=gini, max_depth=5, n_estimators=200, random_state=50;, score=0.780 total time=   0.9s
# [CV 2/5] END criterion=gini, max_depth=5, n_estimators=200, random_state=50;, score=0.767 total time=   1.0s
# [CV 3/5] END criterion=gini, max_depth=5, n_estimators=200, random_state=50;, score=0.787 total time=   1.0s
# [CV 4/5] END criterion=gini, max_depth=5, n_estimators=200, random_state=50;, score=0.807 total time=   1.0s
# [CV 5/5] END criterion=gini, max_depth=5, n_estimators=200, random_state=50;, score=0.747 total time=   1.1s
# [CV 1/5] END criterion=gini, max_depth=5, n_estimators=200, random_state=100;, score=0.787 total time=   1.0s
# [CV 2/5] END criterion=gini, max_depth=5, n_estimators=200, random_state=100;, score=0.760 total time=   1.0s
# [CV 3/5] END criterion=gini, max_depth=5, n_estimators=200, random_state=100;, score=0.780 total time=   1.0s
# [CV 4/5] END criterion=gini, max_depth=5, n_estimators=200, random_state=100;, score=0.807 total time=   0.9s
# [CV 5/5] END criterion=gini, max_depth=5, n_estimators=200, random_state=100;, score=0.747 total time=   1.1s
# [CV 1/5] END criterion=gini, max_depth=6, n_estimators=50, random_state=0;, score=0.793 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=6, n_estimators=50, random_state=0;, score=0.760 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=6, n_estimators=50, random_state=0;, score=0.787 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=6, n_estimators=50, random_state=0;, score=0.793 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=6, n_estimators=50, random_state=0;, score=0.753 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=6, n_estimators=50, random_state=50;, score=0.800 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=6, n_estimators=50, random_state=50;, score=0.773 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=6, n_estimators=50, random_state=50;, score=0.767 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=6, n_estimators=50, random_state=50;, score=0.787 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=6, n_estimators=50, random_state=50;, score=0.753 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=6, n_estimators=50, random_state=100;, score=0.787 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=6, n_estimators=50, random_state=100;, score=0.753 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=6, n_estimators=50, random_state=100;, score=0.767 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=6, n_estimators=50, random_state=100;, score=0.800 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=6, n_estimators=50, random_state=100;, score=0.747 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=6, n_estimators=100, random_state=0;, score=0.780 total time=   0.6s
# [CV 2/5] END criterion=gini, max_depth=6, n_estimators=100, random_state=0;, score=0.760 total time=   0.5s
# [CV 3/5] END criterion=gini, max_depth=6, n_estimators=100, random_state=0;, score=0.793 total time=   0.5s
# [CV 4/5] END criterion=gini, max_depth=6, n_estimators=100, random_state=0;, score=0.800 total time=   0.5s
# [CV 5/5] END criterion=gini, max_depth=6, n_estimators=100, random_state=0;, score=0.740 total time=   0.5s
# [CV 1/5] END criterion=gini, max_depth=6, n_estimators=100, random_state=50;, score=0.793 total time=   0.6s
# [CV 2/5] END criterion=gini, max_depth=6, n_estimators=100, random_state=50;, score=0.747 total time=   0.4s
# [CV 3/5] END criterion=gini, max_depth=6, n_estimators=100, random_state=50;, score=0.787 total time=   0.4s
# [CV 4/5] END criterion=gini, max_depth=6, n_estimators=100, random_state=50;, score=0.800 total time=   0.5s
# [CV 5/5] END criterion=gini, max_depth=6, n_estimators=100, random_state=50;, score=0.740 total time=   0.5s
# [CV 1/5] END criterion=gini, max_depth=6, n_estimators=100, random_state=100;, score=0.787 total time=   0.5s
# [CV 2/5] END criterion=gini, max_depth=6, n_estimators=100, random_state=100;, score=0.753 total time=   0.5s
# [CV 3/5] END criterion=gini, max_depth=6, n_estimators=100, random_state=100;, score=0.780 total time=   0.5s
# [CV 4/5] END criterion=gini, max_depth=6, n_estimators=100, random_state=100;, score=0.800 total time=   0.5s
# [CV 5/5] END criterion=gini, max_depth=6, n_estimators=100, random_state=100;, score=0.747 total time=   0.5s
# [CV 1/5] END criterion=gini, max_depth=6, n_estimators=130, random_state=0;, score=0.780 total time=   0.7s
# [CV 2/5] END criterion=gini, max_depth=6, n_estimators=130, random_state=0;, score=0.760 total time=   0.6s
# [CV 3/5] END criterion=gini, max_depth=6, n_estimators=130, random_state=0;, score=0.780 total time=   0.6s
# [CV 4/5] END criterion=gini, max_depth=6, n_estimators=130, random_state=0;, score=0.800 total time=   0.8s
# [CV 5/5] END criterion=gini, max_depth=6, n_estimators=130, random_state=0;, score=0.747 total time=   0.6s
# [CV 1/5] END criterion=gini, max_depth=6, n_estimators=130, random_state=50;, score=0.787 total time=   0.6s
# [CV 2/5] END criterion=gini, max_depth=6, n_estimators=130, random_state=50;, score=0.753 total time=   0.7s
# [CV 3/5] END criterion=gini, max_depth=6, n_estimators=130, random_state=50;, score=0.787 total time=   0.7s
# [CV 4/5] END criterion=gini, max_depth=6, n_estimators=130, random_state=50;, score=0.800 total time=   0.6s
# [CV 5/5] END criterion=gini, max_depth=6, n_estimators=130, random_state=50;, score=0.747 total time=   0.6s
# [CV 1/5] END criterion=gini, max_depth=6, n_estimators=130, random_state=100;, score=0.787 total time=   0.7s
# [CV 2/5] END criterion=gini, max_depth=6, n_estimators=130, random_state=100;, score=0.753 total time=   0.7s
# [CV 3/5] END criterion=gini, max_depth=6, n_estimators=130, random_state=100;, score=0.793 total time=   0.6s
# [CV 4/5] END criterion=gini, max_depth=6, n_estimators=130, random_state=100;, score=0.800 total time=   0.7s
# [CV 5/5] END criterion=gini, max_depth=6, n_estimators=130, random_state=100;, score=0.747 total time=   0.7s
# [CV 1/5] END criterion=gini, max_depth=6, n_estimators=200, random_state=0;, score=0.780 total time=   1.0s
# [CV 2/5] END criterion=gini, max_depth=6, n_estimators=200, random_state=0;, score=0.753 total time=   1.2s
# [CV 3/5] END criterion=gini, max_depth=6, n_estimators=200, random_state=0;, score=0.780 total time=   1.2s
# [CV 4/5] END criterion=gini, max_depth=6, n_estimators=200, random_state=0;, score=0.813 total time=   1.3s
# [CV 5/5] END criterion=gini, max_depth=6, n_estimators=200, random_state=0;, score=0.747 total time=   1.1s
# [CV 1/5] END criterion=gini, max_depth=6, n_estimators=200, random_state=50;, score=0.780 total time=   1.3s
# [CV 2/5] END criterion=gini, max_depth=6, n_estimators=200, random_state=50;, score=0.753 total time=   1.1s
# [CV 3/5] END criterion=gini, max_depth=6, n_estimators=200, random_state=50;, score=0.780 total time=   1.1s
# [CV 4/5] END criterion=gini, max_depth=6, n_estimators=200, random_state=50;, score=0.813 total time=   1.2s
# [CV 5/5] END criterion=gini, max_depth=6, n_estimators=200, random_state=50;, score=0.747 total time=   1.9s
# [CV 1/5] END criterion=gini, max_depth=6, n_estimators=200, random_state=100;, score=0.780 total time=   7.6s
# [CV 2/5] END criterion=gini, max_depth=6, n_estimators=200, random_state=100;, score=0.760 total time=   4.9s
# [CV 3/5] END criterion=gini, max_depth=6, n_estimators=200, random_state=100;, score=0.787 total time=   3.3s
# [CV 4/5] END criterion=gini, max_depth=6, n_estimators=200, random_state=100;, score=0.807 total time=   2.9s
# [CV 5/5] END criterion=gini, max_depth=6, n_estimators=200, random_state=100;, score=0.753 total time=   1.8s
# [CV 1/5] END criterion=gini, max_depth=7, n_estimators=50, random_state=0;, score=0.773 total time=   0.4s
# [CV 2/5] END criterion=gini, max_depth=7, n_estimators=50, random_state=0;, score=0.760 total time=   0.4s
# [CV 3/5] END criterion=gini, max_depth=7, n_estimators=50, random_state=0;, score=0.787 total time=   0.3s
# [CV 4/5] END criterion=gini, max_depth=7, n_estimators=50, random_state=0;, score=0.820 total time=   0.4s
# [CV 5/5] END criterion=gini, max_depth=7, n_estimators=50, random_state=0;, score=0.740 total time=   0.3s
# [CV 1/5] END criterion=gini, max_depth=7, n_estimators=50, random_state=50;, score=0.787 total time=   0.3s
# [CV 2/5] END criterion=gini, max_depth=7, n_estimators=50, random_state=50;, score=0.773 total time=   0.3s
# [CV 3/5] END criterion=gini, max_depth=7, n_estimators=50, random_state=50;, score=0.773 total time=   0.3s
# [CV 4/5] END criterion=gini, max_depth=7, n_estimators=50, random_state=50;, score=0.787 total time=   0.3s
# [CV 5/5] END criterion=gini, max_depth=7, n_estimators=50, random_state=50;, score=0.767 total time=   0.3s
# [CV 1/5] END criterion=gini, max_depth=7, n_estimators=50, random_state=100;, score=0.787 total time=   0.3s
# [CV 2/5] END criterion=gini, max_depth=7, n_estimators=50, random_state=100;, score=0.753 total time=   0.3s
# [CV 3/5] END criterion=gini, max_depth=7, n_estimators=50, random_state=100;, score=0.773 total time=   0.3s
# [CV 4/5] END criterion=gini, max_depth=7, n_estimators=50, random_state=100;, score=0.813 total time=   0.5s
# [CV 5/5] END criterion=gini, max_depth=7, n_estimators=50, random_state=100;, score=0.753 total time=   0.5s
# [CV 1/5] END criterion=gini, max_depth=7, n_estimators=100, random_state=0;, score=0.787 total time=   1.1s
# [CV 2/5] END criterion=gini, max_depth=7, n_estimators=100, random_state=0;, score=0.760 total time=   1.2s
# [CV 3/5] END criterion=gini, max_depth=7, n_estimators=100, random_state=0;, score=0.787 total time=   1.5s
# [CV 4/5] END criterion=gini, max_depth=7, n_estimators=100, random_state=0;, score=0.813 total time=   1.2s
# [CV 5/5] END criterion=gini, max_depth=7, n_estimators=100, random_state=0;, score=0.747 total time=   1.4s
# [CV 1/5] END criterion=gini, max_depth=7, n_estimators=100, random_state=50;, score=0.787 total time=   1.5s
# [CV 2/5] END criterion=gini, max_depth=7, n_estimators=100, random_state=50;, score=0.767 total time=   1.0s
# [CV 3/5] END criterion=gini, max_depth=7, n_estimators=100, random_state=50;, score=0.780 total time=   1.1s
# [CV 4/5] END criterion=gini, max_depth=7, n_estimators=100, random_state=50;, score=0.807 total time=   1.0s
# [CV 5/5] END criterion=gini, max_depth=7, n_estimators=100, random_state=50;, score=0.747 total time=   1.4s
# [CV 1/5] END criterion=gini, max_depth=7, n_estimators=100, random_state=100;, score=0.780 total time=   3.1s
# [CV 2/5] END criterion=gini, max_depth=7, n_estimators=100, random_state=100;, score=0.760 total time=   3.1s
# [CV 3/5] END criterion=gini, max_depth=7, n_estimators=100, random_state=100;, score=0.787 total time=   2.0s
# [CV 4/5] END criterion=gini, max_depth=7, n_estimators=100, random_state=100;, score=0.800 total time=   1.2s
# [CV 5/5] END criterion=gini, max_depth=7, n_estimators=100, random_state=100;, score=0.773 total time=   1.3s
# [CV 1/5] END criterion=gini, max_depth=7, n_estimators=130, random_state=0;, score=0.787 total time=   1.6s
# [CV 2/5] END criterion=gini, max_depth=7, n_estimators=130, random_state=0;, score=0.760 total time=   1.3s
# [CV 3/5] END criterion=gini, max_depth=7, n_estimators=130, random_state=0;, score=0.787 total time=   1.0s
# [CV 4/5] END criterion=gini, max_depth=7, n_estimators=130, random_state=0;, score=0.820 total time=   0.8s
# [CV 5/5] END criterion=gini, max_depth=7, n_estimators=130, random_state=0;, score=0.747 total time=   0.8s
# [CV 1/5] END criterion=gini, max_depth=7, n_estimators=130, random_state=50;, score=0.780 total time=   0.8s
# [CV 2/5] END criterion=gini, max_depth=7, n_estimators=130, random_state=50;, score=0.760 total time=   0.7s
# [CV 3/5] END criterion=gini, max_depth=7, n_estimators=130, random_state=50;, score=0.787 total time=   0.7s
# [CV 4/5] END criterion=gini, max_depth=7, n_estimators=130, random_state=50;, score=0.813 total time=   0.7s
# [CV 5/5] END criterion=gini, max_depth=7, n_estimators=130, random_state=50;, score=0.740 total time=   0.7s
# [CV 1/5] END criterion=gini, max_depth=7, n_estimators=130, random_state=100;, score=0.793 total time=   0.7s
# [CV 2/5] END criterion=gini, max_depth=7, n_estimators=130, random_state=100;, score=0.767 total time=   0.8s
# [CV 3/5] END criterion=gini, max_depth=7, n_estimators=130, random_state=100;, score=0.793 total time=   0.7s
# [CV 4/5] END criterion=gini, max_depth=7, n_estimators=130, random_state=100;, score=0.813 total time=   0.6s
# [CV 5/5] END criterion=gini, max_depth=7, n_estimators=130, random_state=100;, score=0.773 total time=   0.7s
# [CV 1/5] END criterion=gini, max_depth=7, n_estimators=200, random_state=0;, score=0.787 total time=   1.1s
# [CV 2/5] END criterion=gini, max_depth=7, n_estimators=200, random_state=0;, score=0.767 total time=   1.1s
# [CV 3/5] END criterion=gini, max_depth=7, n_estimators=200, random_state=0;, score=0.780 total time=   1.1s
# [CV 4/5] END criterion=gini, max_depth=7, n_estimators=200, random_state=0;, score=0.813 total time=   1.1s
# [CV 5/5] END criterion=gini, max_depth=7, n_estimators=200, random_state=0;, score=0.747 total time=   1.1s
# [CV 1/5] END criterion=gini, max_depth=7, n_estimators=200, random_state=50;, score=0.780 total time=   1.1s
# [CV 2/5] END criterion=gini, max_depth=7, n_estimators=200, random_state=50;, score=0.760 total time=   1.2s
# [CV 3/5] END criterion=gini, max_depth=7, n_estimators=200, random_state=50;, score=0.773 total time=   1.1s
# [CV 4/5] END criterion=gini, max_depth=7, n_estimators=200, random_state=50;, score=0.813 total time=   1.2s
# [CV 5/5] END criterion=gini, max_depth=7, n_estimators=200, random_state=50;, score=0.747 total time=   1.1s
# [CV 1/5] END criterion=gini, max_depth=7, n_estimators=200, random_state=100;, score=0.787 total time=   1.1s
# [CV 2/5] END criterion=gini, max_depth=7, n_estimators=200, random_state=100;, score=0.767 total time=   1.2s
# [CV 3/5] END criterion=gini, max_depth=7, n_estimators=200, random_state=100;, score=0.787 total time=   1.1s
# [CV 4/5] END criterion=gini, max_depth=7, n_estimators=200, random_state=100;, score=0.820 total time=   1.2s
# [CV 5/5] END criterion=gini, max_depth=7, n_estimators=200, random_state=100;, score=0.767 total time=   1.1s
# [CV 1/5] END criterion=gini, max_depth=8, n_estimators=50, random_state=0;, score=0.793 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=8, n_estimators=50, random_state=0;, score=0.773 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=8, n_estimators=50, random_state=0;, score=0.793 total time=   0.3s
# [CV 4/5] END criterion=gini, max_depth=8, n_estimators=50, random_state=0;, score=0.773 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=8, n_estimators=50, random_state=0;, score=0.760 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=8, n_estimators=50, random_state=50;, score=0.800 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=8, n_estimators=50, random_state=50;, score=0.760 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=8, n_estimators=50, random_state=50;, score=0.793 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=8, n_estimators=50, random_state=50;, score=0.793 total time=   0.3s
# [CV 5/5] END criterion=gini, max_depth=8, n_estimators=50, random_state=50;, score=0.767 total time=   0.3s
# [CV 1/5] END criterion=gini, max_depth=8, n_estimators=50, random_state=100;, score=0.793 total time=   0.3s
# [CV 2/5] END criterion=gini, max_depth=8, n_estimators=50, random_state=100;, score=0.760 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=8, n_estimators=50, random_state=100;, score=0.780 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=8, n_estimators=50, random_state=100;, score=0.807 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=8, n_estimators=50, random_state=100;, score=0.747 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=8, n_estimators=100, random_state=0;, score=0.793 total time=   0.5s
# [CV 2/5] END criterion=gini, max_depth=8, n_estimators=100, random_state=0;, score=0.780 total time=   0.6s
# [CV 3/5] END criterion=gini, max_depth=8, n_estimators=100, random_state=0;, score=0.800 total time=   0.6s
# [CV 4/5] END criterion=gini, max_depth=8, n_estimators=100, random_state=0;, score=0.787 total time=   0.6s
# [CV 5/5] END criterion=gini, max_depth=8, n_estimators=100, random_state=0;, score=0.747 total time=   0.5s
# [CV 1/5] END criterion=gini, max_depth=8, n_estimators=100, random_state=50;, score=0.793 total time=   0.5s
# [CV 2/5] END criterion=gini, max_depth=8, n_estimators=100, random_state=50;, score=0.753 total time=   0.6s
# [CV 3/5] END criterion=gini, max_depth=8, n_estimators=100, random_state=50;, score=0.793 total time=   0.5s
# [CV 4/5] END criterion=gini, max_depth=8, n_estimators=100, random_state=50;, score=0.813 total time=   0.5s
# [CV 5/5] END criterion=gini, max_depth=8, n_estimators=100, random_state=50;, score=0.747 total time=   0.5s
# [CV 1/5] END criterion=gini, max_depth=8, n_estimators=100, random_state=100;, score=0.793 total time=   0.6s
# [CV 2/5] END criterion=gini, max_depth=8, n_estimators=100, random_state=100;, score=0.753 total time=   0.5s
# [CV 3/5] END criterion=gini, max_depth=8, n_estimators=100, random_state=100;, score=0.787 total time=   0.5s
# [CV 4/5] END criterion=gini, max_depth=8, n_estimators=100, random_state=100;, score=0.807 total time=   0.5s
# [CV 5/5] END criterion=gini, max_depth=8, n_estimators=100, random_state=100;, score=0.760 total time=   0.8s
# [CV 1/5] END criterion=gini, max_depth=8, n_estimators=130, random_state=0;, score=0.787 total time=   3.6s
# [CV 2/5] END criterion=gini, max_depth=8, n_estimators=130, random_state=0;, score=0.773 total time=   3.7s
# [CV 3/5] END criterion=gini, max_depth=8, n_estimators=130, random_state=0;, score=0.787 total time=   4.1s
# [CV 4/5] END criterion=gini, max_depth=8, n_estimators=130, random_state=0;, score=0.793 total time=   3.4s
# [CV 5/5] END criterion=gini, max_depth=8, n_estimators=130, random_state=0;, score=0.740 total time=   1.0s
# [CV 1/5] END criterion=gini, max_depth=8, n_estimators=130, random_state=50;, score=0.780 total time=   0.7s
# [CV 2/5] END criterion=gini, max_depth=8, n_estimators=130, random_state=50;, score=0.753 total time=   0.7s
# [CV 3/5] END criterion=gini, max_depth=8, n_estimators=130, random_state=50;, score=0.800 total time=   0.7s
# [CV 4/5] END criterion=gini, max_depth=8, n_estimators=130, random_state=50;, score=0.813 total time=   0.7s
# [CV 5/5] END criterion=gini, max_depth=8, n_estimators=130, random_state=50;, score=0.747 total time=   0.7s
# [CV 1/5] END criterion=gini, max_depth=8, n_estimators=130, random_state=100;, score=0.787 total time=   0.8s
# [CV 2/5] END criterion=gini, max_depth=8, n_estimators=130, random_state=100;, score=0.760 total time=   0.7s
# [CV 3/5] END criterion=gini, max_depth=8, n_estimators=130, random_state=100;, score=0.800 total time=   0.7s
# [CV 4/5] END criterion=gini, max_depth=8, n_estimators=130, random_state=100;, score=0.820 total time=   0.8s
# [CV 5/5] END criterion=gini, max_depth=8, n_estimators=130, random_state=100;, score=0.747 total time=   0.7s
# [CV 1/5] END criterion=gini, max_depth=8, n_estimators=200, random_state=0;, score=0.787 total time=   1.1s
# [CV 2/5] END criterion=gini, max_depth=8, n_estimators=200, random_state=0;, score=0.767 total time=   1.3s
# [CV 3/5] END criterion=gini, max_depth=8, n_estimators=200, random_state=0;, score=0.787 total time=   1.1s
# [CV 4/5] END criterion=gini, max_depth=8, n_estimators=200, random_state=0;, score=0.813 total time=   1.2s
# [CV 5/5] END criterion=gini, max_depth=8, n_estimators=200, random_state=0;, score=0.733 total time=   1.1s
# [CV 1/5] END criterion=gini, max_depth=8, n_estimators=200, random_state=50;, score=0.800 total time=   1.2s
# [CV 2/5] END criterion=gini, max_depth=8, n_estimators=200, random_state=50;, score=0.753 total time=   1.1s
# [CV 3/5] END criterion=gini, max_depth=8, n_estimators=200, random_state=50;, score=0.780 total time=   1.2s
# [CV 4/5] END criterion=gini, max_depth=8, n_estimators=200, random_state=50;, score=0.813 total time=   1.2s
# [CV 5/5] END criterion=gini, max_depth=8, n_estimators=200, random_state=50;, score=0.740 total time=   1.2s
# [CV 1/5] END criterion=gini, max_depth=8, n_estimators=200, random_state=100;, score=0.793 total time=   1.2s
# [CV 2/5] END criterion=gini, max_depth=8, n_estimators=200, random_state=100;, score=0.760 total time=   1.2s
# [CV 3/5] END criterion=gini, max_depth=8, n_estimators=200, random_state=100;, score=0.787 total time=   1.3s
# [CV 4/5] END criterion=gini, max_depth=8, n_estimators=200, random_state=100;, score=0.813 total time=   1.1s
# [CV 5/5] END criterion=gini, max_depth=8, n_estimators=200, random_state=100;, score=0.740 total time=   1.2s
# [CV 1/5] END criterion=gini, max_depth=9, n_estimators=50, random_state=0;, score=0.827 total time=   0.3s
# [CV 2/5] END criterion=gini, max_depth=9, n_estimators=50, random_state=0;, score=0.760 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=9, n_estimators=50, random_state=0;, score=0.793 total time=   0.3s
# [CV 4/5] END criterion=gini, max_depth=9, n_estimators=50, random_state=0;, score=0.820 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=9, n_estimators=50, random_state=0;, score=0.733 total time=   0.3s
# [CV 1/5] END criterion=gini, max_depth=9, n_estimators=50, random_state=50;, score=0.787 total time=   0.3s
# [CV 2/5] END criterion=gini, max_depth=9, n_estimators=50, random_state=50;, score=0.760 total time=   0.3s
# [CV 3/5] END criterion=gini, max_depth=9, n_estimators=50, random_state=50;, score=0.807 total time=   0.3s
# [CV 4/5] END criterion=gini, max_depth=9, n_estimators=50, random_state=50;, score=0.813 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=9, n_estimators=50, random_state=50;, score=0.753 total time=   0.3s
# [CV 1/5] END criterion=gini, max_depth=9, n_estimators=50, random_state=100;, score=0.787 total time=   0.3s
# [CV 2/5] END criterion=gini, max_depth=9, n_estimators=50, random_state=100;, score=0.760 total time=   0.3s
# [CV 3/5] END criterion=gini, max_depth=9, n_estimators=50, random_state=100;, score=0.807 total time=   0.3s
# [CV 4/5] END criterion=gini, max_depth=9, n_estimators=50, random_state=100;, score=0.793 total time=   0.3s
# [CV 5/5] END criterion=gini, max_depth=9, n_estimators=50, random_state=100;, score=0.747 total time=   0.3s
# [CV 1/5] END criterion=gini, max_depth=9, n_estimators=100, random_state=0;, score=0.800 total time=   0.6s
# [CV 2/5] END criterion=gini, max_depth=9, n_estimators=100, random_state=0;, score=0.747 total time=   0.6s
# [CV 3/5] END criterion=gini, max_depth=9, n_estimators=100, random_state=0;, score=0.807 total time=   0.6s
# [CV 4/5] END criterion=gini, max_depth=9, n_estimators=100, random_state=0;, score=0.807 total time=   0.6s
# [CV 5/5] END criterion=gini, max_depth=9, n_estimators=100, random_state=0;, score=0.727 total time=   0.6s
# [CV 1/5] END criterion=gini, max_depth=9, n_estimators=100, random_state=50;, score=0.793 total time=   0.5s
# [CV 2/5] END criterion=gini, max_depth=9, n_estimators=100, random_state=50;, score=0.767 total time=   0.7s
# [CV 3/5] END criterion=gini, max_depth=9, n_estimators=100, random_state=50;, score=0.793 total time=   0.9s
# [CV 4/5] END criterion=gini, max_depth=9, n_estimators=100, random_state=50;, score=0.820 total time=   2.3s
# [CV 5/5] END criterion=gini, max_depth=9, n_estimators=100, random_state=50;, score=0.740 total time=   2.4s
# [CV 1/5] END criterion=gini, max_depth=9, n_estimators=100, random_state=100;, score=0.793 total time=   2.6s
# [CV 2/5] END criterion=gini, max_depth=9, n_estimators=100, random_state=100;, score=0.760 total time=   2.6s
# [CV 3/5] END criterion=gini, max_depth=9, n_estimators=100, random_state=100;, score=0.793 total time=   2.8s
# [CV 4/5] END criterion=gini, max_depth=9, n_estimators=100, random_state=100;, score=0.793 total time=   2.4s
# [CV 5/5] END criterion=gini, max_depth=9, n_estimators=100, random_state=100;, score=0.753 total time=   1.7s
# [CV 1/5] END criterion=gini, max_depth=9, n_estimators=130, random_state=0;, score=0.793 total time=   0.8s
# [CV 2/5] END criterion=gini, max_depth=9, n_estimators=130, random_state=0;, score=0.747 total time=   0.7s
# [CV 3/5] END criterion=gini, max_depth=9, n_estimators=130, random_state=0;, score=0.793 total time=   0.7s
# [CV 4/5] END criterion=gini, max_depth=9, n_estimators=130, random_state=0;, score=0.813 total time=   0.7s
# [CV 5/5] END criterion=gini, max_depth=9, n_estimators=130, random_state=0;, score=0.727 total time=   0.7s
# [CV 1/5] END criterion=gini, max_depth=9, n_estimators=130, random_state=50;, score=0.793 total time=   0.8s
# [CV 2/5] END criterion=gini, max_depth=9, n_estimators=130, random_state=50;, score=0.767 total time=   0.7s
# [CV 3/5] END criterion=gini, max_depth=9, n_estimators=130, random_state=50;, score=0.793 total time=   0.7s
# [CV 4/5] END criterion=gini, max_depth=9, n_estimators=130, random_state=50;, score=0.813 total time=   0.7s
# [CV 5/5] END criterion=gini, max_depth=9, n_estimators=130, random_state=50;, score=0.747 total time=   0.8s
# [CV 1/5] END criterion=gini, max_depth=9, n_estimators=130, random_state=100;, score=0.800 total time=   0.7s
# [CV 2/5] END criterion=gini, max_depth=9, n_estimators=130, random_state=100;, score=0.753 total time=   0.7s
# [CV 3/5] END criterion=gini, max_depth=9, n_estimators=130, random_state=100;, score=0.787 total time=   0.8s
# [CV 4/5] END criterion=gini, max_depth=9, n_estimators=130, random_state=100;, score=0.793 total time=   0.7s
# [CV 5/5] END criterion=gini, max_depth=9, n_estimators=130, random_state=100;, score=0.767 total time=   0.7s
# [CV 1/5] END criterion=gini, max_depth=9, n_estimators=200, random_state=0;, score=0.807 total time=   1.3s
# [CV 2/5] END criterion=gini, max_depth=9, n_estimators=200, random_state=0;, score=0.753 total time=   1.1s
# [CV 3/5] END criterion=gini, max_depth=9, n_estimators=200, random_state=0;, score=0.800 total time=   1.3s
# [CV 4/5] END criterion=gini, max_depth=9, n_estimators=200, random_state=0;, score=0.813 total time=   1.1s
# [CV 5/5] END criterion=gini, max_depth=9, n_estimators=200, random_state=0;, score=0.727 total time=   1.2s
# [CV 1/5] END criterion=gini, max_depth=9, n_estimators=200, random_state=50;, score=0.780 total time=   1.2s
# [CV 2/5] END criterion=gini, max_depth=9, n_estimators=200, random_state=50;, score=0.760 total time=   1.2s
# [CV 3/5] END criterion=gini, max_depth=9, n_estimators=200, random_state=50;, score=0.787 total time=   1.2s
# [CV 4/5] END criterion=gini, max_depth=9, n_estimators=200, random_state=50;, score=0.800 total time=   1.2s
# [CV 5/5] END criterion=gini, max_depth=9, n_estimators=200, random_state=50;, score=0.720 total time=   1.2s
# [CV 1/5] END criterion=gini, max_depth=9, n_estimators=200, random_state=100;, score=0.793 total time=   1.1s
# [CV 2/5] END criterion=gini, max_depth=9, n_estimators=200, random_state=100;, score=0.753 total time=   1.2s
# [CV 3/5] END criterion=gini, max_depth=9, n_estimators=200, random_state=100;, score=0.787 total time=   1.1s
# [CV 4/5] END criterion=gini, max_depth=9, n_estimators=200, random_state=100;, score=0.793 total time=   1.3s
# [CV 5/5] END criterion=gini, max_depth=9, n_estimators=200, random_state=100;, score=0.767 total time=   1.2s
# [CV 1/5] END criterion=gini, max_depth=10, n_estimators=50, random_state=0;, score=0.787 total time=   0.3s
# [CV 2/5] END criterion=gini, max_depth=10, n_estimators=50, random_state=0;, score=0.773 total time=   0.3s
# [CV 3/5] END criterion=gini, max_depth=10, n_estimators=50, random_state=0;, score=0.793 total time=   0.3s
# [CV 4/5] END criterion=gini, max_depth=10, n_estimators=50, random_state=0;, score=0.793 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=10, n_estimators=50, random_state=0;, score=0.753 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=10, n_estimators=50, random_state=50;, score=0.787 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=10, n_estimators=50, random_state=50;, score=0.760 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=10, n_estimators=50, random_state=50;, score=0.780 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=10, n_estimators=50, random_state=50;, score=0.800 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=10, n_estimators=50, random_state=50;, score=0.753 total time=   0.3s
# [CV 1/5] END criterion=gini, max_depth=10, n_estimators=50, random_state=100;, score=0.800 total time=   0.3s
# [CV 2/5] END criterion=gini, max_depth=10, n_estimators=50, random_state=100;, score=0.760 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=10, n_estimators=50, random_state=100;, score=0.793 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=10, n_estimators=50, random_state=100;, score=0.800 total time=   0.3s
# [CV 5/5] END criterion=gini, max_depth=10, n_estimators=50, random_state=100;, score=0.733 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=10, n_estimators=100, random_state=0;, score=0.793 total time=   0.6s
# [CV 2/5] END criterion=gini, max_depth=10, n_estimators=100, random_state=0;, score=0.773 total time=   0.7s
# [CV 3/5] END criterion=gini, max_depth=10, n_estimators=100, random_state=0;, score=0.827 total time=   0.5s
# [CV 4/5] END criterion=gini, max_depth=10, n_estimators=100, random_state=0;, score=0.800 total time=   0.5s
# [CV 5/5] END criterion=gini, max_depth=10, n_estimators=100, random_state=0;, score=0.753 total time=   0.5s
# ...
# [CV 2/5] END criterion=entropy, max_depth=8, n_estimators=130, random_state=100;, score=0.767 total time=   3.3s
# [CV 3/5] END criterion=entropy, max_depth=8, n_estimators=130, random_state=100;, score=0.787 total time=   1.0s
# [CV 4/5] END criterion=entropy, max_depth=8, n_estimators=130, random_state=100;, score=0.820 total time=   0.7s
# [CV 5/5] END criterion=entropy, max_depth=8, n_estimators=130, random_state=100;, score=0.747 total time=   0.5s
# [CV 1/5] END criterion=entropy, max_depth=8, n_estimators=200, random_state=0;, score=0.807 total time=   0.8s
# [CV 2/5] END criterion=entropy, max_depth=8, n_estimators=200, random_state=0;, score=0.753 total time=   0.7s
# [CV 3/5] END criterion=entropy, max_depth=8, n_estimators=200, random_state=0;, score=0.773 total time=   0.6s
# [CV 4/5] END criterion=entropy, max_depth=8, n_estimators=200, random_state=0;, score=0.813 total time=   0.7s
# [CV 5/5] END criterion=entropy, max_depth=8, n_estimators=200, random_state=0;, score=0.740 total time=   0.7s
# [CV 1/5] END criterion=entropy, max_depth=8, n_estimators=200, random_state=50;, score=0.787 total time=   0.6s
# [CV 2/5] END criterion=entropy, max_depth=8, n_estimators=200, random_state=50;, score=0.747 total time=   0.6s
# [CV 3/5] END criterion=entropy, max_depth=8, n_estimators=200, random_state=50;, score=0.787 total time=   0.6s
# [CV 4/5] END criterion=entropy, max_depth=8, n_estimators=200, random_state=50;, score=0.800 total time=   0.6s
# [CV 5/5] END criterion=entropy, max_depth=8, n_estimators=200, random_state=50;, score=0.753 total time=   0.5s
# [CV 1/5] END criterion=entropy, max_depth=8, n_estimators=200, random_state=100;, score=0.800 total time=   0.5s
# [CV 2/5] END criterion=entropy, max_depth=8, n_estimators=200, random_state=100;, score=0.767 total time=   0.6s
# [CV 3/5] END criterion=entropy, max_depth=8, n_estimators=200, random_state=100;, score=0.787 total time=   0.6s
# [CV 4/5] END criterion=entropy, max_depth=8, n_estimators=200, random_state=100;, score=0.813 total time=   0.5s
# [CV 5/5] END criterion=entropy, max_depth=8, n_estimators=200, random_state=100;, score=0.747 total time=   0.5s
# [CV 1/5] END criterion=entropy, max_depth=9, n_estimators=50, random_state=0;, score=0.780 total time=   0.1s
# [CV 2/5] END criterion=entropy, max_depth=9, n_estimators=50, random_state=0;, score=0.780 total time=   0.1s
# [CV 3/5] END criterion=entropy, max_depth=9, n_estimators=50, random_state=0;, score=0.787 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=9, n_estimators=50, random_state=0;, score=0.800 total time=   0.1s
# [CV 5/5] END criterion=entropy, max_depth=9, n_estimators=50, random_state=0;, score=0.747 total time=   0.1s
# [CV 1/5] END criterion=entropy, max_depth=9, n_estimators=50, random_state=50;, score=0.813 total time=   0.1s
# [CV 2/5] END criterion=entropy, max_depth=9, n_estimators=50, random_state=50;, score=0.760 total time=   0.1s
# [CV 3/5] END criterion=entropy, max_depth=9, n_estimators=50, random_state=50;, score=0.787 total time=   0.1s
# [CV 4/5] END criterion=entropy, max_depth=9, n_estimators=50, random_state=50;, score=0.773 total time=   0.1s
# [CV 5/5] END criterion=entropy, max_depth=9, n_estimators=50, random_state=50;, score=0.747 total time=   0.1s
# [CV 1/5] END criterion=entropy, max_depth=9, n_estimators=50, random_state=100;, score=0.787 total time=   0.1s
# [CV 2/5] END criterion=entropy, max_depth=9, n_estimators=50, random_state=100;, score=0.753 total time=   0.1s
# [CV 3/5] END criterion=entropy, max_depth=9, n_estimators=50, random_state=100;, score=0.793 total time=   0.1s
# [CV 4/5] END criterion=entropy, max_depth=9, n_estimators=50, random_state=100;, score=0.813 total time=   0.1s
# [CV 5/5] END criterion=entropy, max_depth=9, n_estimators=50, random_state=100;, score=0.747 total time=   0.1s
# [CV 1/5] END criterion=entropy, max_depth=9, n_estimators=100, random_state=0;, score=0.787 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=9, n_estimators=100, random_state=0;, score=0.773 total time=   0.3s
# [CV 3/5] END criterion=entropy, max_depth=9, n_estimators=100, random_state=0;, score=0.780 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=9, n_estimators=100, random_state=0;, score=0.807 total time=   0.3s
# [CV 5/5] END criterion=entropy, max_depth=9, n_estimators=100, random_state=0;, score=0.740 total time=   0.2s
# [CV 1/5] END criterion=entropy, max_depth=9, n_estimators=100, random_state=50;, score=0.780 total time=   0.3s
# [CV 2/5] END criterion=entropy, max_depth=9, n_estimators=100, random_state=50;, score=0.753 total time=   0.2s
# [CV 3/5] END criterion=entropy, max_depth=9, n_estimators=100, random_state=50;, score=0.800 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=9, n_estimators=100, random_state=50;, score=0.793 total time=   0.3s
# [CV 5/5] END criterion=entropy, max_depth=9, n_estimators=100, random_state=50;, score=0.753 total time=   0.3s
# [CV 1/5] END criterion=entropy, max_depth=9, n_estimators=100, random_state=100;, score=0.793 total time=   0.3s
# [CV 2/5] END criterion=entropy, max_depth=9, n_estimators=100, random_state=100;, score=0.753 total time=   0.3s
# [CV 3/5] END criterion=entropy, max_depth=9, n_estimators=100, random_state=100;, score=0.800 total time=   0.3s
# [CV 4/5] END criterion=entropy, max_depth=9, n_estimators=100, random_state=100;, score=0.793 total time=   0.3s
# [CV 5/5] END criterion=entropy, max_depth=9, n_estimators=100, random_state=100;, score=0.747 total time=   0.3s
# [CV 1/5] END criterion=entropy, max_depth=9, n_estimators=130, random_state=0;, score=0.793 total time=   0.4s
# [CV 2/5] END criterion=entropy, max_depth=9, n_estimators=130, random_state=0;, score=0.780 total time=   0.4s
# [CV 3/5] END criterion=entropy, max_depth=9, n_estimators=130, random_state=0;, score=0.780 total time=   0.4s
# [CV 4/5] END criterion=entropy, max_depth=9, n_estimators=130, random_state=0;, score=0.807 total time=   0.4s
# [CV 5/5] END criterion=entropy, max_depth=9, n_estimators=130, random_state=0;, score=0.747 total time=   0.4s
# [CV 1/5] END criterion=entropy, max_depth=9, n_estimators=130, random_state=50;, score=0.773 total time=   0.6s
# [CV 2/5] END criterion=entropy, max_depth=9, n_estimators=130, random_state=50;, score=0.753 total time=   0.5s
# [CV 3/5] END criterion=entropy, max_depth=9, n_estimators=130, random_state=50;, score=0.800 total time=   0.5s
# [CV 4/5] END criterion=entropy, max_depth=9, n_estimators=130, random_state=50;, score=0.800 total time=   0.5s
# [CV 5/5] END criterion=entropy, max_depth=9, n_estimators=130, random_state=50;, score=0.753 total time=   0.5s
# [CV 1/5] END criterion=entropy, max_depth=9, n_estimators=130, random_state=100;, score=0.800 total time=   0.6s
# [CV 2/5] END criterion=entropy, max_depth=9, n_estimators=130, random_state=100;, score=0.753 total time=   0.5s
# [CV 3/5] END criterion=entropy, max_depth=9, n_estimators=130, random_state=100;, score=0.800 total time=   0.5s
# [CV 4/5] END criterion=entropy, max_depth=9, n_estimators=130, random_state=100;, score=0.807 total time=   0.5s
# [CV 5/5] END criterion=entropy, max_depth=9, n_estimators=130, random_state=100;, score=0.747 total time=   0.5s
# [CV 1/5] END criterion=entropy, max_depth=9, n_estimators=200, random_state=0;, score=0.800 total time=   0.7s
# [CV 2/5] END criterion=entropy, max_depth=9, n_estimators=200, random_state=0;, score=0.780 total time=   0.6s
# [CV 3/5] END criterion=entropy, max_depth=9, n_estimators=200, random_state=0;, score=0.780 total time=   0.6s
# [CV 4/5] END criterion=entropy, max_depth=9, n_estimators=200, random_state=0;, score=0.807 total time=   0.7s
# [CV 5/5] END criterion=entropy, max_depth=9, n_estimators=200, random_state=0;, score=0.747 total time=   0.6s
# [CV 1/5] END criterion=entropy, max_depth=9, n_estimators=200, random_state=50;, score=0.787 total time=   0.5s
# [CV 2/5] END criterion=entropy, max_depth=9, n_estimators=200, random_state=50;, score=0.753 total time=   0.6s
# [CV 3/5] END criterion=entropy, max_depth=9, n_estimators=200, random_state=50;, score=0.793 total time=   0.7s
# [CV 4/5] END criterion=entropy, max_depth=9, n_estimators=200, random_state=50;, score=0.800 total time=   0.6s
# [CV 5/5] END criterion=entropy, max_depth=9, n_estimators=200, random_state=50;, score=0.747 total time=   0.6s
# [CV 1/5] END criterion=entropy, max_depth=9, n_estimators=200, random_state=100;, score=0.787 total time=   0.6s
# [CV 2/5] END criterion=entropy, max_depth=9, n_estimators=200, random_state=100;, score=0.753 total time=   0.6s
# [CV 3/5] END criterion=entropy, max_depth=9, n_estimators=200, random_state=100;, score=0.800 total time=   0.6s
# [CV 4/5] END criterion=entropy, max_depth=9, n_estimators=200, random_state=100;, score=0.813 total time=   0.5s
# [CV 5/5] END criterion=entropy, max_depth=9, n_estimators=200, random_state=100;, score=0.753 total time=   0.6s
# [CV 1/5] END criterion=entropy, max_depth=10, n_estimators=50, random_state=0;, score=0.780 total time=   0.1s
# [CV 2/5] END criterion=entropy, max_depth=10, n_estimators=50, random_state=0;, score=0.753 total time=   0.1s
# [CV 3/5] END criterion=entropy, max_depth=10, n_estimators=50, random_state=0;, score=0.780 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=10, n_estimators=50, random_state=0;, score=0.800 total time=   0.1s
# [CV 5/5] END criterion=entropy, max_depth=10, n_estimators=50, random_state=0;, score=0.733 total time=   0.1s
# [CV 1/5] END criterion=entropy, max_depth=10, n_estimators=50, random_state=50;, score=0.813 total time=   0.1s
# [CV 2/5] END criterion=entropy, max_depth=10, n_estimators=50, random_state=50;, score=0.747 total time=   0.1s
# [CV 3/5] END criterion=entropy, max_depth=10, n_estimators=50, random_state=50;, score=0.793 total time=   0.1s
# [CV 4/5] END criterion=entropy, max_depth=10, n_estimators=50, random_state=50;, score=0.787 total time=   0.1s
# [CV 5/5] END criterion=entropy, max_depth=10, n_estimators=50, random_state=50;, score=0.740 total time=   0.1s
# [CV 1/5] END criterion=entropy, max_depth=10, n_estimators=50, random_state=100;, score=0.800 total time=   0.1s
# [CV 2/5] END criterion=entropy, max_depth=10, n_estimators=50, random_state=100;, score=0.767 total time=   0.1s
# [CV 3/5] END criterion=entropy, max_depth=10, n_estimators=50, random_state=100;, score=0.793 total time=   0.1s
# [CV 4/5] END criterion=entropy, max_depth=10, n_estimators=50, random_state=100;, score=0.813 total time=   0.1s
# [CV 5/5] END criterion=entropy, max_depth=10, n_estimators=50, random_state=100;, score=0.760 total time=   0.1s
# [CV 1/5] END criterion=entropy, max_depth=10, n_estimators=100, random_state=0;, score=0.787 total time=   0.3s
# [CV 2/5] END criterion=entropy, max_depth=10, n_estimators=100, random_state=0;, score=0.753 total time=   0.3s
# [CV 3/5] END criterion=entropy, max_depth=10, n_estimators=100, random_state=0;, score=0.787 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=10, n_estimators=100, random_state=0;, score=0.800 total time=   0.2s
# [CV 5/5] END criterion=entropy, max_depth=10, n_estimators=100, random_state=0;, score=0.740 total time=   0.2s
# [CV 1/5] END criterion=entropy, max_depth=10, n_estimators=100, random_state=50;, score=0.800 total time=   0.3s
# [CV 2/5] END criterion=entropy, max_depth=10, n_estimators=100, random_state=50;, score=0.753 total time=   0.3s
# [CV 3/5] END criterion=entropy, max_depth=10, n_estimators=100, random_state=50;, score=0.787 total time=   0.3s
# [CV 4/5] END criterion=entropy, max_depth=10, n_estimators=100, random_state=50;, score=0.800 total time=   0.2s
# [CV 5/5] END criterion=entropy, max_depth=10, n_estimators=100, random_state=50;, score=0.747 total time=   0.3s
# [CV 1/5] END criterion=entropy, max_depth=10, n_estimators=100, random_state=100;, score=0.807 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=10, n_estimators=100, random_state=100;, score=0.747 total time=   0.3s
# [CV 3/5] END criterion=entropy, max_depth=10, n_estimators=100, random_state=100;, score=0.793 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=10, n_estimators=100, random_state=100;, score=0.800 total time=   0.2s
# [CV 5/5] END criterion=entropy, max_depth=10, n_estimators=100, random_state=100;, score=0.760 total time=   0.3s
# [CV 1/5] END criterion=entropy, max_depth=10, n_estimators=130, random_state=0;, score=0.793 total time=   0.4s
# [CV 2/5] END criterion=entropy, max_depth=10, n_estimators=130, random_state=0;, score=0.773 total time=   0.3s
# [CV 3/5] END criterion=entropy, max_depth=10, n_estimators=130, random_state=0;, score=0.787 total time=   0.3s
# [CV 4/5] END criterion=entropy, max_depth=10, n_estimators=130, random_state=0;, score=0.800 total time=   0.3s
# [CV 5/5] END criterion=entropy, max_depth=10, n_estimators=130, random_state=0;, score=0.747 total time=   0.3s
# [CV 1/5] END criterion=entropy, max_depth=10, n_estimators=130, random_state=50;, score=0.793 total time=   0.3s
# [CV 2/5] END criterion=entropy, max_depth=10, n_estimators=130, random_state=50;, score=0.760 total time=   0.3s
# [CV 3/5] END criterion=entropy, max_depth=10, n_estimators=130, random_state=50;, score=0.800 total time=   0.3s
# [CV 4/5] END criterion=entropy, max_depth=10, n_estimators=130, random_state=50;, score=0.807 total time=   0.3s
# [CV 5/5] END criterion=entropy, max_depth=10, n_estimators=130, random_state=50;, score=0.747 total time=   0.3s
# [CV 1/5] END criterion=entropy, max_depth=10, n_estimators=130, random_state=100;, score=0.807 total time=   0.4s
# [CV 2/5] END criterion=entropy, max_depth=10, n_estimators=130, random_state=100;, score=0.747 total time=   0.3s
# [CV 3/5] END criterion=entropy, max_depth=10, n_estimators=130, random_state=100;, score=0.800 total time=   0.3s
# [CV 4/5] END criterion=entropy, max_depth=10, n_estimators=130, random_state=100;, score=0.807 total time=   0.3s
# [CV 5/5] END criterion=entropy, max_depth=10, n_estimators=130, random_state=100;, score=0.753 total time=   0.3s
# [CV 1/5] END criterion=entropy, max_depth=10, n_estimators=200, random_state=0;, score=0.787 total time=   0.6s
# [CV 2/5] END criterion=entropy, max_depth=10, n_estimators=200, random_state=0;, score=0.760 total time=   0.6s
# [CV 3/5] END criterion=entropy, max_depth=10, n_estimators=200, random_state=0;, score=0.780 total time=   0.6s
# [CV 4/5] END criterion=entropy, max_depth=10, n_estimators=200, random_state=0;, score=0.807 total time=   0.6s
# [CV 5/5] END criterion=entropy, max_depth=10, n_estimators=200, random_state=0;, score=0.753 total time=   0.6s
# [CV 1/5] END criterion=entropy, max_depth=10, n_estimators=200, random_state=50;, score=0.780 total time=   0.6s
# [CV 2/5] END criterion=entropy, max_depth=10, n_estimators=200, random_state=50;, score=0.760 total time=   0.5s
# [CV 3/5] END criterion=entropy, max_depth=10, n_estimators=200, random_state=50;, score=0.787 total time=   0.6s
# [CV 4/5] END criterion=entropy, max_depth=10, n_estimators=200, random_state=50;, score=0.807 total time=   0.7s
# [CV 5/5] END criterion=entropy, max_depth=10, n_estimators=200, random_state=50;, score=0.740 total time=   0.6s
# [CV 1/5] END criterion=entropy, max_depth=10, n_estimators=200, random_state=100;, score=0.813 total time=   0.6s
# [CV 2/5] END criterion=entropy, max_depth=10, n_estimators=200, random_state=100;, score=0.747 total time=   0.7s
# [CV 3/5] END criterion=entropy, max_depth=10, n_estimators=200, random_state=100;, score=0.800 total time=   0.7s
# [CV 4/5] END criterion=entropy, max_depth=10, n_estimators=200, random_state=100;, score=0.807 total time=   0.7s
# [CV 5/5] END criterion=entropy, max_depth=10, n_estimators=200, random_state=100;, score=0.760 total time=   0.8s
# GridSearchCV(cv=5, estimator=RandomForestClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': range(3, 11),
#                          'n_estimators': [50, 100, 130, 200],
#                          'random_state': [0, 50, 100]},
#              verbose=3)

# %%
GridSearchCV(cv=5, estimator=RandomForestClassifier(),
             param_grid={'criterion': ['gini', 'entropy'],
                         'max_depth': range(3, 11),
                         'n_estimators': [50, 100, 130, 200],
                         'random_state': [0, 50, 100]},
             verbose=3)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': range(3, 11),
#                          'n_estimators': [50, 100, 130, 200],
#                          'random_state': [0, 50, 100]},
#              verbose=3)

# %%
gs1.best_params_
# Out:
# {'criterion': 'gini', 'max_depth': 10, 'n_estimators': 100, 'random_state': 0}

# %%
from sklearn.ensemble import RandomForestClassifier
rs1=RandomForestClassifier(criterion='gini', max_depth= 10, n_estimators= 100, random_state= 0)
rs1.fit(scaled_train,y_train)
y_pred3=rs1.predict(scaled_test)
accuracy_score(y_test,y_pred3)*100
# Out:
# 85.2589641434263

# %% [markdown]
# ## XG Boost Classifier

# %%
from xgboost import XGBClassifier
xgb=XGBClassifier()
xgb.fit(scaled_train,y_train)
y_pred4=xgb.predict(scaled_test)
accuracy_score(y_test,y_pred4)*100
# Out:
# 78.08764940239044

# %%
param_grid_xg={
    
    "n_estimators":[100,50,20,30], 
    "subsample":[1.0,2.0,3.0], 
    "criterion":['friedman_mse','squared_error'],
    "min_samples_split":[2, 3,4], 
    "min_samples_leaf":[1,2,3]
}

# %%
gs2=GridSearchCV(rs,param_grid=param_grid_xg,cv=5,verbose=3)

# %%
gs2.fit(scaled_train,y_train)
# Out:
# Fitting 5 folds for each of 216 candidates, totalling 1080 fits
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15208/2143794985.py in <module>
# ----> 1 gs2.fit(scaled_train,y_train)
#
# ~\anaconda3\lib\site-packages\sklearn\model_selection\_search.py in fit(self, X, y, groups, **fit_params)
#     872                 return results
#     873
# --> 874             self._run_search(evaluate_candidates)
#     875
#     876             # multimetric is determined here because in the case of a callable
#
# ~\anaconda3\lib\site-packages\sklearn\model_selection\_search.py in _run_search(self, evaluate_candidates)
#    1386     def _run_search(self, evaluate_candidates):
#    1387         """Search all candidates in param_grid"""
# -> 1388         evaluate_candidates(ParameterGrid(self.param_grid))
#    1389
#    1390
#
# ~\anaconda3\lib\site-packages\sklearn\model_selection\_search.py in evaluate_candidates(candidate_params, cv, more_results)
#     819                     )
#     820
# --> 821                 out = parallel(
#     822                     delayed(_fit_and_score)(
#     823                         clone(base_estimator),
#
# ~\anaconda3\lib\site-packages\sklearn\utils\parallel.py in __call__(self, iterable)
#      61             for delayed_func, args, kwargs in iterable
#      62         )
# ---> 63         return super().__call__(iterable_with_config)
#      64
#      65
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#    1083             # remaining jobs.
#    1084             self._iterating = False
# -> 1085             if self.dispatch_one_batch(iterator):
#    1086                 self._iterating = self._original_iterator is not None
#    1087
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in dispatch_one_batch(self, iterator)
#     899                 return False
#     900             else:
# --> 901                 self._dispatch(tasks)
#     902                 return True
#     903
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in _dispatch(self, batch)
#     817         with self._lock:
#     818             job_idx = len(self._jobs)
# --> 819             job = self._backend.apply_async(batch, callback=cb)
#     820             # A job can complete so quickly than its callback is
#     821             # called before we get here, causing self._jobs to
#
# ~\anaconda3\lib\site-packages\joblib\_parallel_backends.py in apply_async(self, func, callback)
#     206     def apply_async(self, func, callback=None):
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#     210             callback(result)
#
# ~\anaconda3\lib\site-packages\joblib\_parallel_backends.py in __init__(self, batch)
#     595         # Don't delay the application, to avoid keeping the input
#     596         # arguments in memory
# --> 597         self.results = batch()
#     598
#     599     def get(self):
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in __call__(self)
#     286         # change the default number of processes to -1
#     287         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288             return [func(*args, **kwargs)
#     289                     for func, args, kwargs in self.items]
#     290
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in <listcomp>(.0)
#     286         # change the default number of processes to -1
#     287         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288             return [func(*args, **kwargs)
#     289                     for func, args, kwargs in self.items]
#     290
#
# ~\anaconda3\lib\site-packages\sklearn\utils\parallel.py in __call__(self, *args, **kwargs)
#     121             config = {}
#     122         with config_context(**config):
# --> 123             return self.function(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     672             cloned_parameters[k] = clone(v, safe=False)
#     673
# --> 674         estimator = estimator.set_params(**cloned_parameters)
#     675
#     676     start_time = time.time()
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in set_params(self, **params)
#     203             if key not in valid_params:
#     204                 local_valid_params = self._get_param_names()
# --> 205                 raise ValueError(
#     206                     f"Invalid parameter {key!r} for estimator {self}. "
#     207                     f"Valid parameters are: {local_valid_params!r}."
#
# ValueError: Invalid parameter 'subsample' for estimator RandomForestClassifier(criterion='friedman_mse'). Valid parameters are: ['bootstrap', 'ccp_alpha', 'class_weight', 'criterion', 'max_depth', 'max_features', 'max_leaf_nodes', 'max_samples', 'min_impurity_decrease', 'min_samples_leaf', 'min_samples_split', 'min_weight_fraction_leaf', 'n_estimators', 'n_jobs', 'oob_score', 'random_state', 'verbose', 'warm_start'].
